# %% [markdown]
# # 01 — Скачивание данных (Sentinel-2, Landsat, RGI)
#
# **Требует:** аутентификации Google Earth Engine (`earthengine authenticate` в терминале)
# и доступа к интернету. Этот ноутбук НЕ выполняется в облачной песочнице —
# запускайте его локально (Anaconda + `conda activate glaciers`).
#
# Результат: GeoTIFF-композиты в `data/raw/sentinel2/` и `data/raw/landsat/`
# (после скачивания вручную из Google Drive, папка `GlacierKZ`),
# а также контуры RGI в `data/rgi/`.

# %%
import sys

sys.path.append('..')

import os

import ee
import geemap

from src import config, data_loader

ee.Initialize()
print(ee.String('Earth Engine работает!').getInfo())
# Out:
# /Users/dulatnurlanuly/miniforge3/envs/glaciers/lib/python3.10/site-packages/google/api_core/_python_version_support.py:273: FutureWarning: You are using a Python version (3.10.20) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# Earth Engine работает!

# %% [markdown]
# ## Область исследования
#
# Используем `config.STUDY_AREA_BBOX` — Заилийский Алатау, бассейн рек
# Малая/Большая Алматинка (ледники Туюксу, Богдановича и др.).

# %%
STUDY_AREA = ee.Geometry.BBox(*config.STUDY_AREA_BBOX)

m = geemap.Map()
m.centerObject(STUDY_AREA, 10)
m.addLayer(STUDY_AREA, {}, 'Study area')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[43.000145721713785, 76.99999999999976], controls=(WidgetControl(options=['position', 'transparent_…

# %% [markdown]
# ## Sentinel-2 (2015–2024)

# %%
os.makedirs(config.DATA_RAW_SENTINEL2, exist_ok=True)

for year in config.YEARS_SENTINEL2:
    print(f"\n--- Обрабатываем {year} ---")
    img = data_loader.get_sentinel2(year, STUDY_AREA)
    if img is not None:
        print(f"  Каналы: {img.bandNames().getInfo()}")
    data_loader.export_year_to_drive(img, year, STUDY_AREA, prefix='sentinel2')

print("\nВсе задачи запущены! Проверь прогресс на code.earthengine.google.com/tasks")
print("После завершения — скачай файлы из Google Drive (папка GlacierKZ) в data/raw/sentinel2/")
print("Индексы NDSI/NDWI/BSI/EVI будут добавлены локально в data_loader.load_image().")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --- Обрабатываем 2015 ---
# 2015: найдено 0 снимков с облачностью <15%
#   Нет снимков! Пробуем с облачностью <30%...
#   2015: снимков нет даже при 30% — пропускаем.
#   sentinel2_2015: изображение пустое — пропускаем.
#
# --- Обрабатываем 2016 ---
# 2016: найдено 3 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2016 отправлена в GEE.
#
# --- Обрабатываем 2017 ---
# 2017: найдено 6 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2017 отправлена в GEE.
#
# --- Обрабатываем 2018 ---
# 2018: найдено 6 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2018 отправлена в GEE.
#
# --- Обрабатываем 2019 ---
# 2019: найдено 32 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2019 отправлена в GEE.
#
# --- Обрабатываем 2020 ---
# 2020: найдено 16 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2020 отправлена в GEE.
#
# --- Обрабатываем 2021 ---
# 2021: найдено 28 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2021 отправлена в GEE.
#
# --- Обрабатываем 2022 ---
# 2022: найдено 31 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2022 отправлена в GEE.
#
# --- Обрабатываем 2023 ---
# 2023: найдено 23 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2023 отправлена в GEE.
#
# --- Обрабатываем 2024 ---
# 2024: найдено 14 снимков с облачностью <15%
#   Каналы: ['B2', 'B3', 'B4', 'B8', 'B8A', 'B11', 'B12']
#   Задача sentinel2_2024 отправлена в GEE.
#
# Все задачи запущены! Проверь прогресс на code.earthengine.google.com/tasks
# После завершения — скачай файлы из Google Drive (папка GlacierKZ) в data/raw/sentinel2/
# Индексы NDSI/NDWI/BSI/EVI будут добавлены локально в data_loader.load_image().

# %% [markdown]
# ## Landsat (2000–2013)

# %%
os.makedirs(config.DATA_RAW_LANDSAT, exist_ok=True)

for year in config.YEARS_LANDSAT:
    print(f"\n--- Обрабатываем {year} (Landsat) ---")
    img = data_loader.get_landsat(year, STUDY_AREA)
    if img is not None:
        img = data_loader.add_indices(img)
    data_loader.export_year_to_drive(img, year, STUDY_AREA, prefix='landsat')

print("\nЗадачи Landsat запущены. Скачай результаты в data/raw/landsat/")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# --- Обрабатываем 2000 (Landsat) ---
# 2000 (Landsat): найдено 4 снимков
#   Задача landsat_2000 отправлена в GEE.
#
# --- Обрабатываем 2003 (Landsat) ---
# 2003 (Landsat): найдено 3 снимков
#   Задача landsat_2003 отправлена в GEE.
#
# --- Обрабатываем 2005 (Landsat) ---
# 2005 (Landsat): найдено 3 снимков
#   Задача landsat_2005 отправлена в GEE.
#
# --- Обрабатываем 2008 (Landsat) ---
# 2008 (Landsat): найдено 5 снимков
#   Задача landsat_2008 отправлена в GEE.
#
# --- Обрабатываем 2010 (Landsat) ---
# 2010 (Landsat): найдено 7 снимков
#   Задача landsat_2010 отправлена в GEE.
#
# --- Обрабатываем 2013 (Landsat) ---
# 2013 (Landsat): найдено 6 снимков
#   Задача landsat_2013 отправлена в GEE.
#
# Задачи Landsat запущены. Скачай результаты в data/raw/landsat/

# %% [markdown]
# ## RGI 7.0 — контуры ледников
#
# Скачай регион 13 (Central Asia) с https://www.glims.org/RGI/rgi70_dl.html
# (или через `ee.FeatureCollection('GLIMS/current')`), сохрани shapefile в `data/rgi/`.

# %%
# Вариант: контуры ледников прямо из Earth Engine (GLIMS)
rgi_fc = ee.FeatureCollection('GLIMS/current')
kz_glaciers = rgi_fc.filterBounds(STUDY_AREA)
print('Ледников в области исследования:', kz_glaciers.size().getInfo())

# Экспорт в Drive как shapefile/GeoJSON для дальнейшей работы в geopandas/QGIS
task = ee.batch.Export.table.toDrive(
    collection=kz_glaciers,
    description='rgi_study_area',
    folder='GlacierKZ',
    fileNamePrefix='rgi_study_area',
    fileFormat='SHP',
)
task.start()
print('Экспорт контуров RGI запущен -> data/rgi/rgi_study_area.shp')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Ледников в области исследования: 1455
# Экспорт контуров RGI запущен -> data/rgi/rgi_study_area.shp

# %% [markdown]
# ## Чек-лист после выполнения
#
# - [ ] Sentinel-2 за минимум 5 лет (2015–2024) скачаны в `data/raw/sentinel2/`
# - [ ] Landsat за 2000–2013 скачаны в `data/raw/landsat/`
# - [ ] RGI контуры в `data/rgi/`
# - [ ] Все файлы открываются в QGIS без ошибок (Layer -> Add Raster/Vector Layer)
